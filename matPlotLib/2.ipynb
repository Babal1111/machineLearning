# %%
import matplotlib.pyplot as plt

x = ["mony","tue","wed","th","fri","sat"];
y= [10,20,30,40,50,10]

plt.plot(x,y)
plt.title("Boutique Sales")
plt.xlabel("week days")
plt.ylabel("no of sales")

plt.show();
