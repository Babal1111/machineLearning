# %%
import matploylib.pyplot as plt

x= ["swif","tiago","nexon","innova"]
y= [100,200,400,200]
plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matploylib.pyplot as plt
#       3 x= ["swif","tiago","nexon","innova"]
#       4 y= [100,200,400,200]
#
# ModuleNotFoundError: No module named 'matploylib'
